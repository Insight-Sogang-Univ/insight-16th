# %% [markdown]
# # **시각화 과제**
# ▶ 앞으로 토나오게(...) 사용할 **그래프 유형을 학습**하는 데에 주안점을 두고 진행해주세요!

# %%
# 필요한 모듈 import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn-v0_8")  # matplotlib style 설정

# 사진 파일 불러오기
# !pip install IPython
from IPython.display import Image

# 문법 변경에 의한 경고를 무시
import warnings
warnings.filterwarnings('ignore')

# 폰트 안 깨지게 설정
import platform
from matplotlib import font_manager

def set_korean_font():
    """
    운영체제에 맞는 한글 폰트를 설정합니다.
    """
    os_name = platform.system()
    
    if os_name == 'Windows':
        font_name = 'Malgun Gothic'
    elif os_name == 'Darwin': # macOS
        font_name = 'AppleGothic'

    # 전역으로 폰트 설정
    plt.rc('font', family=font_name)
    
    # 마이너스 부호 깨짐 방지 설정
    plt.rc('axes', unicode_minus=False)
    
    print(f"'{font_name}' 폰트로 설정되었습니다.")

set_korean_font()
# Out:
# Requirement already satisfied: IPython in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (9.17.1)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from IPython) (0.4.6)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from IPython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from IPython) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from IPython) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from IPython) (3.0.53)
# Requirement already satisfied: psutil>=7 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from IPython) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from IPython) (2.21.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from IPython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from IPython) (5.16.1)
# Requirement already satisfied: wcwidth>=0.1.4 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython) (0.8.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jedi>=0.18.2->IPython) (0.8.7)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from stack_data>=0.6.0->IPython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from stack_data>=0.6.0->IPython) (3.0.2)
# Requirement already satisfied: pure-eval in C:\Users\wooky\AppData\Local\Programs\Python\Python313\Lib\site-packages (from stack_data>=0.6.0->IPython) (0.2.3)
# 'Malgun Gothic' 폰트로 설정되었습니다.

# %% [markdown]
# ### (0) titanic_set.csv 데이터를 변수 data로 불러오세요.

# %%
# pandas 모듈의 read_csv() 이용하여 코드 작성
data=pd.read_csv('./titanic_set.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> countplot(범주형), histplot(수치형) </span>
# ▶ 데이터의 분포와 빈도를 시각화하는 기본적인 플롯

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=data,x='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=data,x='Survived',hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
plt.figure(figsize=(5,4))
sns.histplot(data=data,x="Age",hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ### (1) 승선항(Embarked)별 생존여부를 hue파라미터를 이용해 확인해보세요.

# %%
# 코드 작성
plt.figure(figsize=(5,4))
sns.countplot(data=data,x='Embarked',hue='Survived')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# ### (2) 나이대별 생존여부를 hue파라미터를 이용해 확인해보세요.

# %%
plt.figure(figsize=(5,4))

# 여기에 시각화 코드를 작성해주세요.
sns.histplot(data=data,x="Age",hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ### Q. 'hue'의 역할은 무엇일까요? (일반적으로 hue파라미터에 사용하는 변수의 종류와 함께 역할을 써주세요.)
#
# A. hue에는 주로 범주형 변수를 넣어 내가 보려고 하는 데이터를 hue에 넣은 변수를 기준으로 구분해서 볼 수 있게 해줍니다.

# %% [markdown]
# # <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> displot, kdeplot(커널밀도함수) </span>

# %% [markdown]
# ▶ 히스토그램을 매끄럽게 곡선으로 연결한 그래프 <br>
# ▶ displot 함수의 kde 파라미터에 True를 전달하면 밀도 곡선이 표현됨

# %%
sns.displot(data["Age"],kde=True)

# %%
sns.kdeplot(data["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### (3) displot으로 요금(Fare)의 분포를 확인해보세요.

# %%
# 코드 작성
sns.displot(data['Fare'], kde=True)

# %% [markdown]
# # <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> barplot(범주형), pointplot(연속형)</span>
# ▶ x에 따른 y의 평균값을 나타내는 그래프

# %%
sns.barplot(data=data, x='Sex', y='Age', hue="Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
plt.figure(figsize=(18,4))
sns.pointplot(data=data,x='Age',y='Fare',linestyles="")
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# ### (4) Pclass 별 생존율을 barplot을 통해 확인해보세요.

# %%
# 코드 작성
sns.barplot(data=data, x='Pclass', y='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# ### 빈칸에 알맞은 단어를 써주세요.
# #### barplot과 pointplot은 x에 따른 y의 평균값을 나타내는 그래프이다.

# %% [markdown]
# # <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> boxplot</span>
#
# ▶데이터의 중앙값, 사분위수, 그리고 이상치를 시각적으로 표현하는 그래프

# %%
sns.boxplot(data=data, x='Pclass', y='Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> scatterplot</span>
#
# ▶ 데이터를 점으로 찍어 분포를 보는 산점도 그래프 <br>
# ▶ 두 연속변수간의 상관관계를 확인할 때 유용함

# %%
sns.scatterplot(data=data, x="Age",y='Fare',hue="Survived", 
                size='Pclass', sizes=(50,330))
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# # <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> regplot</span>
#
# ▶ 회귀선이 추가된 산점도 그래프 <br>
# ▶ 두 개의 연속 변수 사이의 산점도를 그리고 선형회귀분석에 의한 회귀선을 함께 나타냄

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.regplot(x='Age',y='Fare',data=data,ax=ax1) ## 회귀선 있는 버전
sns.regplot(x='Age',y='Fare',data=data, ax=ax2, fit_reg=False) ## 회귀선 없는 버전

plt.show()

# %% [markdown]
# # <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> pieplot</span>
#
# ▶ 데이터의 비율을 시각적으로 표현하는 데 사용

# %%
embarked_counts = data['Embarked'].value_counts()
plt.pie(embarked_counts, labels=embarked_counts.index, 
        autopct='%1.1f%%', startangle=140)
plt.title("Embarked")
# Out:
# Text(0.5, 1.0, 'Embarked')

# %% [markdown]
# ### (5) Pclass를 파이플롯으로 나타내보세요.

# %%
# 'embarked_counts'에 새로운 값을 할당하여 코드 작성
embarked_counts = data['Pclass'].value_counts()
plt.pie(embarked_counts, labels=embarked_counts.index, 
        autopct='%1.1f%%', startangle=140)
plt.title("Pclass")
# Out:
# Text(0.5, 1.0, 'Pclass')

# %% [markdown]
# # <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> heatmap</span>
#
# ▶ 변수간 상관계수를 직관적 볼 수 있는 그래프 <br>
# ▶ corr()함수로 변수간의 상관계수를 구하고 이를 히트맵에 표현할 수 있음

# %% [markdown]
# ### (6) 수치형 변수만 모아 새로운 데이터 프레임을 만들고 히트맵을 찍어보겠습니다.
# #### Q. 현재 데이터에서 수치형 변수 네가지를 쓰세요.
# #### A. SibSp(동승한 형제 또는 배우자 수), Parch(동승한 부모 또는 자녀 수), Age(나이), Fare(요금)입니다.

# %%
df= data[['SibSp','Parch','Age', 'Fare']]
sns.heatmap(df.corr(),annot=True) 
#annot 파라미터는 상관계수 표시 여부 결정
# Out:
# <Axes: >

# %%
data['Age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> catplot</span>
#
# ▶ 범주형 데이터와 연속형 데이터를 함께 시각화할 수 있음

# %% [markdown]
# 순서형(범주형) 변수 'Pclass'와 수치형(연속형) 변수 'Fare'를 함께 보겠습니다.

# %%
sns.catplot(x='Pclass', y='Fare', hue='Sex', data=data)

# %% [markdown]
# # <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> 여러 개의 플롯 결합 </span>
#
# ▶ 여러 개의 그래프를 찍는 공식 <br>
# f, ax = plt.subplots(1, 2, figsize=(12, 4))
#
# ▶ f는 도화지, ax는 만화를 그릴 때의 하나의 컷!
# 즉, 도화지를 1행 2열로 쪼개겠다는 의미이고 figsize는 도화지의 크기임

# %%
f, ax = plt.subplots(1, 2, figsize=(12, 4))  # 1행 2열의 서브플롯 생성
sns.countplot(x='Pclass', data=data,ax=ax[0])
sns.barplot(x='Sex', y='Age',data=data, hue="Survived",ax=ax[1])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> pairplot</span>
#
# ▶ 다변량 데이터셋에서 각 변수 쌍 간의 관계를 시각적으로 표현하는 그래프 <br>
# ▶ 변수 간의 분포와 상관관계를 파악하는 데 사용함

# %%
sns.pairplot(data=data, hue="Survived")

# %% [markdown]
# # <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> 직접 찍어보기</span>

# %% [markdown]
# ### (7) 그래프를 그릴 2x2칸을 설정해보세요.

# %%
# 2행 2열의 서브플롯 생성
f, ax = plt.subplots(2, 2, figsize=(12, 4))
sns.countplot(x='Embarked', data=data, ax=ax[0,0])
sns.countplot(x='Embarked', hue='Pclass', data=data, ax=ax[0,1]) 
sns.barplot(x='Pclass', y='Survived', hue='Sex', data=data, ax=ax[1,0])
sns.barplot(x='Pclass', y='Survived', data=data, ax=ax[1,1])
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# ### (8) 1행 1열에 승선항(Embarked)별 승객의 수를 알 수 있는 시각화를 진행해보세요.
#
# Q. 승객이 많은 승선항 순으로 나열하면? <br>
# A. S ⇒ C ⇒ Q

# %%
# 위 마크다운에 '?' 채우고 코드 작성
sns.countplot(x='Embarked', data=data, ax=ax[0,0])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# ### (9) 2행 2열에 객실 등급(Pclass)에 따른 생존율을 알아 볼 수 있는 시각화를 진행해보세요.
#
# Q. 생존률이 가장 높은 등급은? <BR>
# A. 1등급

# %%
# 위 마크다운에 '?' 채우고 코드 작성
sns.barplot(x='Pclass', y='Survived', data=data, ax=ax[1,1])
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# ### (10) 나머지 칸에 본인이 파악하고 싶은 정보를 자유롭게 시각화하고, 인사이트를 작성해보세요.
#
# Q. 알아낸 것은? <BR>
# A1. C항구에서 승선한 고객 중 절반 정도가 1등급 고객인 것으로 보아 C항구 주변에는 구매력이 높은 고객이 거주하는 동네가 있을 것이다.
# <BR>A2. 객실 등급이 높을수록 고객의 생존률이 높다.
# <BR>A3. 객실 등급 3등급의 여성의 생존률이 객실 등급 1등급 남성의 생존률보다 높은 것으로 보아 객실 등급과 무관하게 여성의 생존률이 남성의 생존률보다 높다는 것을 알 수 있다.

# %%
# 위 마크다운 채우고 자유롭게 코드 작성
sns.countplot(x='Embarked', hue='Pclass', data=data, ax=ax[0,1])  #승선항별 객실등급별 고객 수.
sns.violinplot(x='Embarked', y='Age', hue='Survived', data=data, split=True, ax=ax[1,0])
ax[1,0].set_yticks(range(0, 110, 10))
# Out:
# [<matplotlib.axis.YTick at 0x1d83b294550>,
#  <matplotlib.axis.YTick at 0x1d83b323610>,
#  <matplotlib.axis.YTick at 0x1d83b3239d0>,
#  <matplotlib.axis.YTick at 0x1d83b323d90>,
#  <matplotlib.axis.YTick at 0x1d83b5f4190>,
#  <matplotlib.axis.YTick at 0x1d83b5f4550>,
#  <matplotlib.axis.YTick at 0x1d83b5f4910>,
#  <matplotlib.axis.YTick at 0x1d83b5f4cd0>,
#  <matplotlib.axis.YTick at 0x1d83b5f5090>,
#  <matplotlib.axis.YTick at 0x1d83b5f5450>,
#  <matplotlib.axis.YTick at 0x1d83b5f5810>]
