# %% [markdown]
# # Pandas 과제

# %% [markdown]
# 실습에서 했던 것처럼, 실제로는 대부분 csv 등 외부 파일에서 데이터를 불러오거나
# 리스트·딕셔너리로 만든 데이터를 데이터프레임으로 변환해 사용합니다.
#
# 이번 과제에서는 **타이타닉** 데이터셋(Seaborn 내장)을 불러와 사용합니다. (다음 차시에서도 씁니다!)

# %%
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
titanic = sns.load_dataset('titanic')
print("titanic 변수 type: ", type(titanic))
# Out:
# titanic 변수 type:  <class 'pandas.DataFrame'>

# %% [markdown]
# # 1. 데이터 확인

# %%
data = titanic
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %% [markdown]
# 방금 본 `info()` 결과를 바탕으로, `titanic.shape`의 출력 결과를 예측해보세요.

# %% [markdown]
# > _"자신의 예측을 여기에 적어주세요!"_

# %%
print("DataFrame 크기: ", titanic.shape)
# Out:
# DataFrame 크기:  (891, 15)

# %%
value_counts = data["survived"].value_counts()
print(value_counts)
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# 위 `value_counts()` 결과를 보고, **생존자(1)와 사망자(0) 중 어느 쪽이 더 많은지** 숫자를 근거로 한 문장으로 설명하세요.
#
# > _"여기에 답을 작성하세요!"_

# %% [markdown]
# # 2. 열 단위 추출 - 단일 칼럼
#
# 같은 열을 **인덱싱 / loc / iloc** 세 가지 방법으로 꺼내 보며 차이를 익혀봅시다!

# %% [markdown]
# ### 인덱싱으로 `survived` 열 추출하기
# `data[열이름]` 형태입니다. 빈칸을 채워 `survived` 열을 `surv`에 저장하세요.

# %%
# 추출한 데이터를 surv라는 변수에 저장합니다.
surv = data[***]

print(surv)
type(surv)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64
# pandas.Series

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:09107ec3-0b8c-4433-885e-8cbdc200496e.png)

# %% [markdown]
# 위 결과의 타입은 `Series`였습니다. **Series와 DataFrame의 차이**를 한 문장으로 설명하세요.
#
# > _"여기에 답을 작성하세요!"_

# %% [markdown]
# ### loc으로 같은 열 추출하기
# 아래 코드는 `loc`으로 `survived`를 꺼냅니다. `:` 와 `'survived'`가 각각 무슨 뜻인지 주석을 달아주세요.

# %%
surv1 = data.loc[:, 'survived']   # ← 이 줄을 설명하는 주석을 달아보세요
# :        →
# 'survived' →

print(surv1)
type(surv1)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64
# pandas.Series

# %% [markdown]
# ### iloc으로 같은 열 추출하기
# `iloc`은 **이름 대신 정수 위치**를 씁니다. `survived` (맨 왼쪽 열)을 추출해서 `surv2`에 저장하세요.

# %%
surv2 = data.***   # iloc 사용

print(surv2)
type(surv2)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64
# pandas.Series

# %% [markdown]
# ### 오류 찾기
# 아래 코드는 오류가 발생합니다. **오류의 원인**을 다음 마크다운 셀에 설명하고, 올바르게 고쳐 실행하세요.

# %% [markdown]
# `data.iloc[:, 'survived']` 는 왜 오류일까요?
#
# > _여기에 답을 작성하세요!_

# %%
# 아래 오류 코드의 주석을 풀어 오류를 직접 확인해 보세요.
# data.iloc[:, 'survived']

# 올바르게 고친 코드:
***
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %% [markdown]
# ### 단일 칼럼을 뽑되 **DataFrame 형태로 유지**하려면?
#
# 대괄호를 한 번 더 감싸면 됩니다.
# -> (`data[['survived']]`, `data.loc[:, ['survived']]`, `data.iloc[:, [0]]`)

# %% [markdown]
# ### 출력 예측하기
# `data['survived']` 와 `data[['survived']]` 의 **타입**은 각각 무엇일까요? 실행 전에 예측해 보세요.

# %% [markdown]
# > _자신의 예측을 여기에 적어주세요!_

# %%
surv  = data[['survived']]
surv1 = data.loc[:, ['survived']]
surv2 = data.iloc[:, [0]]
print(type(surv), type(surv1), type(surv2))
# Out:
# <class 'pandas.DataFrame'> <class 'pandas.DataFrame'> <class 'pandas.DataFrame'>

# %% [markdown]
# # 3. 열 단위 추출 - 다중 칼럼
#
# 두 개 이상의 열을 동시에 뽑으려면 **반드시 리스트**로 열 이름을 넘겨야 합니다.
# 예) `data[['age', 'sibsp', 'parch']]`

# %% [markdown]
# ### 인덱싱으로 `age`, `sibsp`, `parch` 세 열을 추출해 `df`에 저장하세요.

# %%
df = ***
df
# Out:
#       age  sibsp  parch
# 0    22.0      1      0
# 1    38.0      1      0
# 2    26.0      0      0
# 3    35.0      1      0
# 4    35.0      0      0
# ..    ...    ...    ...
# 886  27.0      0      0
# 887  19.0      0      0
# 888   NaN      1      2
# 889  26.0      0      0
# 890  32.0      0      0
#
# [891 rows x 3 columns]

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:4948367b-5834-48c9-9c58-671264b9361c.png)

# %% [markdown]
# ### 오류 찾기
# 아래 코드는 오류(`KeyError`)가 납니다. 오류의 원인을 설명하고 수정하세요!

# %% [markdown]
# `data['pclass', 'age']` 는 왜 `KeyError`일까요?
#
# > _여기에 답을 작성하세요!_

# %%
# data['pclass', 'age']   # ← 오류. 주석을 풀어 확인해 보세요.

# 고친 코드:
***
# Out:
#      pclass   age
# 0         3  22.0
# 1         1  38.0
# 2         3  26.0
# 3         1  35.0
# 4         3  35.0
# ..      ...   ...
# 886       2  27.0
# 887       1  19.0
# 888       3   NaN
# 889       1  26.0
# 890       3  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# ### loc으로 다중 칼럼 추출하기
# 각 부분(`:`, 리스트)이 무슨 뜻인지 주석으로 설명하세요.

# %%
df1 = data.loc[:, ['age', 'sibsp', 'parch']]
# :                       →
# ['age','sibsp','parch'] →
df1
# Out:
#       age  sibsp  parch
# 0    22.0      1      0
# 1    38.0      1      0
# 2    26.0      0      0
# 3    35.0      1      0
# 4    35.0      0      0
# ..    ...    ...    ...
# 886  27.0      0      0
# 887  19.0      0      0
# 888   NaN      1      2
# 889  26.0      0      0
# 890  32.0      0      0
#
# [891 rows x 3 columns]

# %% [markdown]
# ### iloc으로 열 슬라이싱
#
# `iloc`은 **정수 위치 범위**로 자릅니다. `age`, `sibsp`, `parch`는 각각 3, 4, 5번째 열이므로 `3:6`으로 뽑을 수 있어요.
# (loc으로 같은 걸 하려면 이름으로 `data.loc[:, 'age':'parch']`)

# %%
df2 = data.iloc[:, 3:6]
df2
# Out:
#       age  sibsp  parch
# 0    22.0      1      0
# 1    38.0      1      0
# 2    26.0      0      0
# 3    35.0      1      0
# 4    35.0      0      0
# ..    ...    ...    ...
# 886  27.0      0      0
# 887  19.0      0      0
# 888   NaN      1      2
# 889  26.0      0      0
# 890  32.0      0      0
#
# [891 rows x 3 columns]

# %% [markdown]
# 같은 세 열을 뽑는데 iloc은 `3:6`(6 제외), loc은 `'age':'parch'`(parch 포함)를 씁니다. **왜 끝을 포함하는지/안 하는지가 다른지** 한 문장으로 설명하세요.
#
# > _여기에 답을 작성하세요!_

# %% [markdown]
# # 4. 행 단위 추출
#
# 슬라이싱은 `start:end` 로 범위를 지정합니다. **번호 기반(iloc/기본 슬라이싱)은 끝을 제외**, **이름 기반(loc)은 끝을 포함**한다는 점이 핵심입니다.

# %% [markdown]
# ### `data[101:201]` 은 몇 개의 행을 반환할까요? 이유와 함께 예측해 보세요.

# %% [markdown]
# > _자신의 예측을 여기에 적어주세요!_

# %%
df = data[101:201]
df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 101         0       3    male   NaN  ...   NaN  Southampton     no   True
# 102         0       1    male  21.0  ...     D  Southampton     no  False
# 103         0       3    male  33.0  ...   NaN  Southampton     no   True
# 104         0       3    male  37.0  ...   NaN  Southampton     no  False
# 105         0       3    male  28.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 196         0       3    male   NaN  ...   NaN   Queenstown     no   True
# 197         0       3    male  42.0  ...   NaN  Southampton     no  False
# 198         1       3  female   NaN  ...   NaN   Queenstown    yes   True
# 199         0       2  female  24.0  ...   NaN  Southampton     no   True
# 200         0       3    male  28.0  ...   NaN  Southampton     no   True
#
# [100 rows x 15 columns]

# %% [markdown]
# ### `data.loc[201:300]` 과 `data.iloc[201:300]` 은 각각 **몇 개의 행**을 반환할까요? 이유와 함께 쓰세요.
#
# > _여기에 답을 작성하세요!_

# %%
df1 = data.loc[201:300, :]
df1
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 201         0       3    male   NaN  ...   NaN  Southampton     no  False
# 202         0       3    male  34.0  ...   NaN  Southampton     no   True
# 203         0       3    male  45.5  ...   NaN    Cherbourg     no   True
# 204         1       3    male  18.0  ...   NaN  Southampton    yes   True
# 205         0       3  female   2.0  ...     G  Southampton     no  False
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 296         0       3    male  23.5  ...   NaN    Cherbourg     no   True
# 297         0       1  female   2.0  ...     C  Southampton     no  False
# 298         1       1    male   NaN  ...     C  Southampton    yes   True
# 299         1       1  female  50.0  ...     B    Cherbourg    yes  False
# 300         1       3  female   NaN  ...   NaN   Queenstown    yes   True
#
# [100 rows x 15 columns]

# %% [markdown]
# ### iloc으로 인덱스가 301~400인 행 추출하기
# iloc은 끝을 포함하지 않으니 end 값에 주의하세요!

# %%
df2 = data.***[***, ***]
df2
# Out:
#      survived  pclass     sex    age  ...  deck  embark_town  alive  alone
# 301         1       3    male    NaN  ...   NaN   Queenstown    yes  False
# 302         0       3    male  19.00  ...   NaN  Southampton     no   True
# 303         1       2  female    NaN  ...     E   Queenstown    yes   True
# 304         0       3    male    NaN  ...   NaN  Southampton     no   True
# 305         1       1    male   0.92  ...     C  Southampton    yes  False
# ..        ...     ...     ...    ...  ...   ...          ...    ...    ...
# 396         0       3  female  31.00  ...   NaN  Southampton     no   True
# 397         0       2    male  46.00  ...   NaN  Southampton     no   True
# 398         0       2    male  23.00  ...   NaN  Southampton     no   True
# 399         1       2  female  28.00  ...   NaN  Southampton    yes   True
# 400         1       3    male  39.00  ...   NaN  Southampton    yes   True
#
# [100 rows x 15 columns]

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:c4e4ade5-904b-400c-a085-794f80bc3b5b.png)

# %% [markdown]
# # 5. 행과 열 복합 추출
#
# 이제 행과 열 조건을 함께 줘서 원하는 부분만 뽑아봅시다. 결과 변수는 `df`로 통일합니다.

# %% [markdown]
# ### `loc`으로 **행 100~120**, **열 `age`, `fare`** 를 추출하세요.

# %%
df = data.***[***,***]
df
# Out:
#       age      fare
# 100  28.0    7.8958
# 101   NaN    7.8958
# 102  21.0   77.2875
# 103  33.0    8.6542
# 104  37.0    7.9250
# 105  28.0    7.8958
# 106  21.0    7.6500
# 107   NaN    7.7750
# 108  38.0    7.8958
# 109   NaN   24.1500
# 110  47.0   52.0000
# 111  14.5   14.4542
# 112  22.0    8.0500
# 113  20.0    9.8250
# 114  17.0   14.4583
# 115  21.0    7.9250
# 116  70.5    7.7500
# 117  29.0   21.0000
# 118  24.0  247.5208
# 119   2.0   31.2750
# 120  21.0   73.5000

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:3aa5b802-0209-4fba-a110-68d6d5517caa.png)

# %% [markdown]
# ### Fancy 인덱싱 + 라벨 슬라이싱
# `loc`으로 **행 0, 2, 4, 7번**과 **열 `age`부터 `fare`까지**를 추출하세요.

# %%
df = data.loc[***, ***]
df
# Out:
#     age  sibsp  parch    fare
# 0  22.0      1      0   7.250
# 2  26.0      0      0   7.925
# 4  35.0      0      0   8.050
# 7   2.0      3      1  21.075

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:dd9e7d9c-d1fa-49a6-a510-f0c36eafa656.png)

# %% [markdown]
# ### `iloc`으로 **인덱스가 10~20인 행**, **2번째 열부터 5번째 열까지**를 추출하세요. (iloc은 끝 제외에 주의하세요!)

# %%
df = data.***[***, ***]
df
# Out:
#     pclass     sex   age  sibsp
# 10       3  female   4.0      1
# 11       1  female  58.0      0
# 12       3    male  20.0      0
# 13       3    male  39.0      1
# 14       3  female  14.0      0
# 15       2  female  55.0      0
# 16       3    male   2.0      4
# 17       2    male   NaN      0
# 18       3  female  31.0      1
# 19       3  female   NaN      0
# 20       2    male  35.0      0

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:39fa35d8-ffcc-4b2e-90f6-3b327754455e.png)

# %% [markdown]
# ### `iloc`으로 **행 [0, 2, 4, 6]**, **열 [1, 3, 5]** 를 뽑으려 합니다. 결과의 **shape**(행 수, 열 수)를 먼저 예측한 뒤, 코드를 작성하세요.

# %% [markdown]
# > _자신의 예측을 여기에 적어주세요!_

# %%
df = data.***[***, ***]
df
# Out:
#    pclass   age  parch
# 0       3  22.0      0
# 2       3  26.0      0
# 4       3  35.0      0
# 6       1  54.0      0

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:309578b9-841e-4e40-bb94-e158bbbbb414.png)

# %% [markdown]
# `loc`으로 **행 라벨 200번**, **열 `survived`, `pclass`, `sex`** 를 뽑되 **DataFrame 형태를 유지**하세요.

# %%
df = data.***[***, ***]
print(df)
type(df)
# Out:
#      survived  pclass   sex
# 200         0       3  male
# pandas.DataFrame

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:1e15f794-d879-4975-9eb3-6da2be994871.png)

# %% [markdown]
# 위에서 행을 `200`이 아니라 `[200]`으로 감싼 이유는 무엇일까요?
#
# > _여기에 답을 작성하세요!_

# %% [markdown]
# # 6. 불리언 인덱싱 - `df[조건문]`
#
# 조건문은 각 행에 대해 True/False를 만들고, **True인 행만** 남깁니다.

# %% [markdown]
# ### `adult_male` 열의 값이 `True`인 행만 추출하세요.

# %%
df = data[*** == ***]
df
# Out:
#      survived  pclass   sex   age  ...  deck  embark_town  alive  alone
# 0           0       3  male  22.0  ...   NaN  Southampton     no  False
# 4           0       3  male  35.0  ...   NaN  Southampton     no   True
# 5           0       3  male   NaN  ...   NaN   Queenstown     no   True
# 6           0       1  male  54.0  ...     E  Southampton     no   True
# 12          0       3  male  20.0  ...   NaN  Southampton     no   True
# ..        ...     ...   ...   ...  ...   ...          ...    ...    ...
# 883         0       2  male  28.0  ...   NaN  Southampton     no   True
# 884         0       3  male  25.0  ...   NaN  Southampton     no   True
# 886         0       2  male  27.0  ...   NaN  Southampton     no   True
# 889         1       1  male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3  male  32.0  ...   NaN   Queenstown     no   True
#
# [537 rows x 15 columns]

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:220ce6a7-8b12-4887-a21c-2e42af1b24f8.png)

# %% [markdown]
# ### `age`가 20세 **미만**인 행만 추출하세요.

# %%
df = data[*** < ***]
df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 7           0       3    male   2.0  ...   NaN  Southampton     no  False
# 9           1       2  female  14.0  ...   NaN    Cherbourg    yes  False
# 10          1       3  female   4.0  ...     G  Southampton    yes  False
# 14          0       3  female  14.0  ...   NaN  Southampton     no   True
# 16          0       3    male   2.0  ...   NaN   Queenstown     no  False
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 855         1       3  female  18.0  ...   NaN  Southampton    yes  False
# 869         1       3    male   4.0  ...   NaN  Southampton    yes  False
# 875         1       3  female  15.0  ...   NaN    Cherbourg    yes   True
# 877         0       3    male  19.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
#
# [164 rows x 15 columns]

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:682a919b-242a-4a0e-82bb-409e6c5e94ed.png)

# %% [markdown]
# ### 아래 코드가 무엇을 하는지 각 부분을 주석으로 설명하세요.

# %%
df = data.loc[data['survived'] == 1, 'survived']
# data['survived'] == 1 →
# , 'survived'          →
df
# Out:
# 1      1
# 2      1
# 3      1
# 8      1
# 9      1
#       ..
# 875    1
# 879    1
# 880    1
# 887    1
# 889    1
# Name: survived, Length: 342, dtype: int64

# %% [markdown]
# ### **나이 20세 이상 & 성별 female** 인 행을 추출하세요.
# tip: (각 조건은 괄호로 감싸고 `&` 사용)

# %%
df = data[*** & ***]
df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 8           1       3  female  27.0  ...   NaN  Southampton    yes  False
# 11          1       1  female  58.0  ...     C  Southampton    yes   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 874         1       2  female  28.0  ...   NaN    Cherbourg    yes  False
# 879         1       1  female  56.0  ...     C    Cherbourg    yes  False
# 880         1       2  female  25.0  ...   NaN  Southampton    yes  False
# 882         0       3  female  22.0  ...   NaN  Southampton     no   True
# 885         0       3  female  39.0  ...   NaN   Queenstown     no  False
#
# [186 rows x 15 columns]

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:52057890-4477-4d73-8556-f78abaeff2ff.png)

# %% [markdown]
# ### `sibsp`가 0이 아니거나 `parch`가 0이 아닌 행을 추출하세요.
# tip: `!=` 와 `|` 사용

# %%
df = data[*** | ***]
df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 7           0       3    male   2.0  ...   NaN  Southampton     no  False
# 8           1       3  female  27.0  ...   NaN  Southampton    yes  False
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 874         1       2  female  28.0  ...   NaN    Cherbourg    yes  False
# 879         1       1  female  56.0  ...     C    Cherbourg    yes  False
# 880         1       2  female  25.0  ...   NaN  Southampton    yes  False
# 885         0       3  female  39.0  ...   NaN   Queenstown     no  False
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
#
# [354 rows x 15 columns]

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:86911c77-961e-436c-97f7-1a854555e087.png)

# %% [markdown]
# ### 다음을 모두 만족하는 행을 추출하세요:
# - 생존자(`survived == 1`)
# - 나이가 5세 미만 **또는** 70세 이상
# - 좌석 등급(`pclass`)이 1등석 **또는** 2등석
#
# tip: 큰 조건은 `&`로 잇고, '또는' 부분은 안쪽에서 `|`로 묶으세요.

# %%
df = data[*** & *** & ***]
df
# Out:
#      survived  pclass     sex    age  ...  deck  embark_town  alive  alone
# 43          1       2  female   3.00  ...   NaN    Cherbourg    yes  False
# 78          1       2    male   0.83  ...   NaN  Southampton    yes  False
# 183         1       2    male   1.00  ...     F  Southampton    yes  False
# 193         1       2    male   3.00  ...     F  Southampton    yes  False
# 305         1       1    male   0.92  ...     C  Southampton    yes  False
# 340         1       2    male   2.00  ...     F  Southampton    yes  False
# 407         1       2    male   3.00  ...   NaN  Southampton    yes  False
# 445         1       1    male   4.00  ...     A  Southampton    yes  False
# 530         1       2  female   2.00  ...   NaN  Southampton    yes  False
# 618         1       2  female   4.00  ...     F  Southampton    yes  False
# 630         1       1    male  80.00  ...     A  Southampton    yes   True
# ...

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:b987904d-371a-44c7-b3af-4e7d131212b3.png)

# %% [markdown]
# # 7. 인덱스 설정

# %% [markdown]
# ### `set_index`로 `age`를 인덱스로 지정합니다. 각 줄을 주석으로 설명하고, `inplace=True`가 하는 일을 작성하세요.

# %%
df1 = data[:]
df1.set_index('age', inplace=True)
df1
# df1 = data[:]  →
# set_index      →
# inplace=True   →
# Out:
#       survived  pclass     sex  sibsp  ...  deck  embark_town alive  alone
# age                                    ...
# 22.0         0       3    male      1  ...   NaN  Southampton    no  False
# 38.0         1       1  female      1  ...     C    Cherbourg   yes  False
# 26.0         1       3  female      0  ...   NaN  Southampton   yes   True
# 35.0         1       1  female      1  ...     C  Southampton   yes  False
# 35.0         0       3    male      0  ...   NaN  Southampton    no   True
# ...        ...     ...     ...    ...  ...   ...          ...   ...    ...
# 27.0         0       2    male      0  ...   NaN  Southampton    no   True
# 19.0         1       1  female      0  ...     B  Southampton   yes   True
# NaN          0       3  female      1  ...   NaN  Southampton    no  False
# 26.0         1       1    male      0  ...     C    Cherbourg   yes   True
# 32.0         0       3    male      0  ...   NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
df1.sort_index()
# Out:
#       survived  pclass     sex  sibsp  ...  deck  embark_town alive  alone
# age                                    ...
# 0.42         1       3    male      0  ...   NaN    Cherbourg   yes  False
# 0.67         1       2    male      1  ...   NaN  Southampton   yes  False
# 0.75         1       3  female      2  ...   NaN    Cherbourg   yes  False
# 0.75         1       3  female      2  ...   NaN    Cherbourg   yes  False
# 0.83         1       2    male      0  ...   NaN  Southampton   yes  False
# ...        ...     ...     ...    ...  ...   ...          ...   ...    ...
# NaN          0       3    male      0  ...   NaN    Cherbourg    no   True
# NaN          0       3  female      8  ...   NaN  Southampton    no  False
# NaN          0       3    male      0  ...   NaN  Southampton    no   True
# NaN          0       3    male      0  ...   NaN  Southampton    no   True
# NaN          0       3  female      1  ...   NaN  Southampton    no  False
#
# [891 rows x 14 columns]

# %% [markdown]
# ### `sort_index()` 와 `sort_values(by=...)` 는 무엇을 기준으로 정렬하는지 각각 한 문장으로 구분해 설명하세요.
#
# > _여기에 답을 작성하세요!_

# %% [markdown]
# ### df1의 인덱스를 리셋하고, 두 옵션 `inplace=True`, `drop=False`의 의미를 주석으로 작성하세요.

# %%
df1.***(inplace=True, drop=False) #
df1
# Out:
#       age  survived  pclass     sex  ...  deck  embark_town  alive  alone
# 0    22.0         0       3    male  ...   NaN  Southampton     no  False
# 1    38.0         1       1  female  ...     C    Cherbourg    yes  False
# 2    26.0         1       3  female  ...   NaN  Southampton    yes   True
# 3    35.0         1       1  female  ...     C  Southampton    yes  False
# 4    35.0         0       3    male  ...   NaN  Southampton     no   True
# ..    ...       ...     ...     ...  ...   ...          ...    ...    ...
# 886  27.0         0       2    male  ...   NaN  Southampton     no   True
# 887  19.0         1       1  female  ...     B  Southampton    yes   True
# 888   NaN         0       3  female  ...   NaN  Southampton     no  False
# 889  26.0         1       1    male  ...     C    Cherbourg    yes   True
# 890  32.0         0       3    male  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:05e8238c-3f06-4971-b9d9-9541f2f254fa.png)

# %% [markdown]
# `drop=True`였다면 결과가 어떻게 달라졌을까요?
#
# > _여기에 답을 작성하세요!_

# %% [markdown]
# ### (참고) 열 순서 바꾸기 & 열 이름만 바꾸기
# 아래는 실행하며 확인만 해보세요!

# %%
data4 = data.loc[0:5, 'survived':'age']
columns = list(data4.columns.values)
print(columns, '\n')
# Out:
# ['survived', 'pclass', 'sex', 'age']

# %%
columns_reversed = list(reversed(columns))
data_reversed = data4[columns_reversed]
data_reversed
# Out:
#     age     sex  pclass  survived
# 0  22.0    male       3         0
# 1  38.0  female       1         1
# 2  26.0  female       3         1
# 3  35.0  female       1         1
# 4  35.0    male       3         0
# 5   NaN    male       3         0

# %% [markdown]
# # 8. 데이터 조작 - 추가 / 삭제 / 정렬

# %% [markdown]
# ### 원본 보호를 위해 `data2 = data.copy()` 로 복사본을 만든 뒤, 값이 모두 `0`인 `Age_0` 열을 추가하세요.

# %%
data2 = data.copy()
data2[***] = ***
data2.head()
# Out:
#    survived  pclass     sex   age  sibsp  ...  deck  embark_town alive  alone Age_0
# 0         0       3    male  22.0      1  ...   NaN  Southampton    no  False     0
# 1         1       1  female  38.0      1  ...     C    Cherbourg   yes  False     0
# 2         1       3  female  26.0      0  ...   NaN  Southampton   yes   True     0
# 3         1       1  female  35.0      1  ...     C  Southampton   yes  False     0
# 4         0       3    male  35.0      0  ...   NaN  Southampton    no   True     0
#
# [5 rows x 16 columns]

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:0a9182d9-7b3f-4d69-85ff-126a65280911.png)

# %%
data2['Age_0'] = data2['Age_0'] + 100
data2.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  ...  deck  embark_town alive  alone Age_0
# 0         0       3    male  22.0      1  ...   NaN  Southampton    no  False   100
# 1         1       1  female  38.0      1  ...     C    Cherbourg   yes  False   100
# 2         1       3  female  26.0      0  ...   NaN  Southampton   yes   True   100
# 3         1       1  female  35.0      1  ...     C  Southampton   yes  False   100
# 4         0       3    male  35.0      0  ...   NaN  Southampton    no   True   100
#
# [5 rows x 16 columns]

# %% [markdown]
# ### 방금 만든 `Age_0` 열을 삭제하세요. (열 삭제일 때는 축을 어떻게 지정했죠?)

# %%
data2.***('Age_0', axis=***, inplace=True)
data2
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:2325652a-cc8b-428b-9f18-ab203652528e.png)

# %% [markdown]
# `axis=1` 은 무엇을 의미하나요? `axis=0` 이었다면 어떤 일이 벌어졌을까요?
#
# > _여기에 답을 작성하세요!_

# %% [markdown]
# ### 인덱스를 기준으로 **내림차순** 정렬하세요. (원본 data2를 바꾸도록 옵션을 설정하세요!)

# %%
data2.***(***, ***)
data2
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
#
# [891 rows x 15 columns]

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:e8c2a059-8dd6-4afd-a898-28a60569c23f.png)

# %% [markdown]
# ### 다중 키 정렬
# 실행하기 전에, 다음 두 코드가 각각 어떤 역할인지 주석을 달아서 설명해주세요!

# %%
titanic_sorted = data.sort_values(by=['embark_town', 'pclass'], ascending=[False, False]) #
titanic_sorted.head(3) #
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [3 rows x 15 columns]

# %% [markdown]
# # 9. 데이터프레임 병합 - concat / merge

# %%
data3 = data.copy()
d1 = data3.iloc[0:100]
d2 = data3.iloc[700:800]
print(d1.shape, d2.shape)
# Out:
# (100, 15) (100, 15)

# %% [markdown]
# ### `concat`으로 `d1`과 `d2`를 **위아래로(행 방향)** 이어붙이세요.
# 행방향 결합은 axis를 어떻게 설정해야할까요?

# %%
concat_data = pd.***(***, ***)
concat_data
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 795         0       2    male  39.0  ...   NaN  Southampton     no   True
# 796         1       1  female  49.0  ...     D  Southampton    yes   True
# 797         1       3  female  31.0  ...   NaN  Southampton    yes   True
# 798         0       3    male  30.0  ...   NaN    Cherbourg     no   True
# 799         0       3  female  30.0  ...   NaN  Southampton     no  False
#
# [200 rows x 15 columns]

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:e2fd0a73-07b0-47a9-9651-d49595e5b798.png)

# %% [markdown]
# ### `concat` 과 `merge` 는 둘 다 데이터프레임을 합치지만 방식이 다릅니다. 두 방식의 차이를 한두 문장으로 설명하세요.
#
# > _여기에 답을 작성하세요!_

# %%
d3 = data3.iloc[4:14, 3:12:3]
d4 = data3.iloc[10:18, 3:12:2]
print('d3:', list(d3.columns))
print('d4:', list(d4.columns))
# Out:
# d3: ['age', 'fare', 'who']
# d4: ['age', 'parch', 'embarked', 'who', 'deck']

# %% [markdown]
# ### `d3`과 `d4`를 `age`를 기준으로 **교집합(inner)** 병합하세요.

# %%
merge_inner = pd.***(***, ***, ***, ***)
merge_inner
# Out:
#     age     fare  who_x  parch embarked  who_y deck
# 0   NaN   8.4583    man      0        S    man  NaN
# 1   2.0  21.0750  child      1        Q  child  NaN
# 2  14.0  30.0708  child      0        S  child  NaN
# 3   4.0  16.7000  child      1        S  child    G
# 4  58.0  26.5500  woman      0        S  woman    C
# 5  20.0   8.0500    man      0        S    man  NaN
# 6  39.0  31.2750    man      5        S    man  NaN

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:11e21fb9-8e7f-4db5-bb37-d0a3df8cf913.png)

# %% [markdown]
# ### 그렇다면 `how = 'outer'`로 설정하면 어떻게 될까요?
# 실행 전에 결과를 예측해보고, 아래에 작성해주세요!
#
# > _자신의 예측 결과를 여기에 작성해주세요!_

# %%
merge_outer = pd.merge(d3, d4, how='outer', on='age')
merge_outer
# Out:
#      age     fare  who_x  parch embarked  who_y deck
# 0    2.0  21.0750  child    1.0        Q  child  NaN
# 1    4.0  16.7000  child    1.0        S  child    G
# 2   14.0  30.0708  child    0.0        S  child  NaN
# 3   20.0   8.0500    man    0.0        S    man  NaN
# 4   27.0  11.1333  woman    NaN      NaN    NaN  NaN
# 5   35.0   8.0500    man    NaN      NaN    NaN  NaN
# 6   39.0  31.2750    man    5.0        S    man  NaN
# 7   54.0  51.8625    man    NaN      NaN    NaN  NaN
# 8   55.0      NaN    NaN    0.0        S  woman  NaN
# 9   58.0  26.5500  woman    0.0        S  woman    C
# 10   NaN   8.4583    man    0.0        S    man  NaN

# %% [markdown]
# ### inner 결과보다 outer 결과의 **행 수가 더 많은(또는 같은) 이유**와, outer에서 생기는 **`NaN`(빈 값)의 의미**를 설명하세요.
#
# > _여기에 답을 작성하세요!_

# %% [markdown]
# # 10. 집계 함수와 그룹화

# %%
data.count()   # 열마다 결측이 아닌 값의 개수 (axis=0 기본)
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
data[['age', 'fare']].mean()
# Out:
# age     29.699118
# fare    32.204208
# dtype: float64

# %% [markdown]
# ### `data.groupby('pclass')` **만** 실행하면 무엇이 출력될까요? (실제 집계 결과일까요, 아니면 다른 무엇일까요?)

# %% [markdown]
# > _자신의 예측을 여기에 적어주세요!_

# %%
data_groupby = data.groupby('pclass')
print(type(data_groupby))
# Out:
# <class 'pandas.api.typing.DataFrameGroupBy'>

# %% [markdown]
# ### 아래 두 줄이 각각 무엇을 하는지 주석으로 설명하세요.

# %%
data.groupby(['pclass', 'survived']).size()
# groupby(['pclass','survived']) →
# .size()                        →
# Out:
# pclass  survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# dtype: int64

# %% [markdown]
# ### `pclass`로 그룹화한 뒤, `['pclass', 'survived']` 두 열만 골라 각 그룹의 개수를 `count()`로 세어보세요.

# %%
data_groupby = data.***(***)[***].***
data_groupby
# Out:
#         pclass  survived
# pclass
# 1          216       216
# 2          184       184
# 3          491       491

# %% [markdown]
# 다음과 같이 나오면 정답입니다!
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### agg로 여러 집계 한 번에 하기
# `pclass`로 그룹화한 뒤, `age`는 최댓값, `sibsp`는 합, `fare`는 평균을 한 번에 구하세요.
# tip: `{'age': 'max', ...}` 형태의 딕셔너리를 `agg()`에 넘기면 여러 집계를 한 번에 할 수 있어요.

# %%
agg_format = ***
data.groupby('pclass').agg(agg_format)
# Out:
#          age  sibsp       fare
# pclass
# 1       80.0     90  84.154687
# 2       70.0     74  20.662183
# 3       74.0    302  13.675550

# %% [markdown]
# ### `groupby`는 왜 **집계함수(count, mean, sum 등)와 함께** 써야 의미가 있을까요? 지금까지 배운 내용을 바탕으로 한두 문장으로 정리하세요.
#
# > _여기에 답을 작성하세요!_

# %% [markdown]
# # 고생하셨습니다!
