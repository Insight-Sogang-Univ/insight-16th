# %% [markdown]
# - 자료의 척도
# - 기술통계
#     - 기술통계의 3요소
# - 확률분포
#     - 대표적인 분포 모형
# - 추론통계
#     - 추정
#     - 가설검정 과정
#     - 자료형에 따른 검정 방법

# %% [markdown]
# # 통계
#
# ## **자료**의 척도
# **자료:** _설명과 해석을 위하여 수집되고 분석되며, 요약되는 사실과 수치_
#
# ### 질적 자료
# - 명목척도
# - 서열척도
#
# ### 양적 자료
# - 구간(등간)척도
# - 비율척도
#
#
#
# ## 기술통계
# _데이터를 있는 그대로 설명하고 이해하는 데 중점을 둔 통계 방법_
#
#
# ### 기술통계의 3요소
#
# #### 중심화 경향
# - 평균, 중앙값, 최빈값
#
# #### 자료의 산포
# - 범위, 분산, 표준편차, 사분위수, 사분위간 범위, 변동계수
#
# #### 자료의 정리 및 시각화
# - 히스토그램, 박스플롯, 파이차트
#
# ## 확률분포
# _확률변수가 특정한 값을 가질 확률을 나타내는 함수_ <BR>
# **확률변수:** random한 세계에서 어떤 특정 사건이 발생할 때 나타날 수 있는 모든 경우의 수를 특정 값으로 대응시키는 함수
#
# - 이산확률분포
# - 연속확률분포
#
# ### 대표적인 분포 모형
#
# #### 정규 분포
# ![image.png](attachment:image.png)
#
# - 가장 잘 알려진 (연속)확률분포
# - 많은 자연 현상과 사회 현상이 정규분포를 따르는 것으로 알려져 있음
#
# #### Z분포(표준정규분포)
# ![image-2.png](attachment:image-2.png)
#
# - 평균이 0이고 표준편차가 1이 되도록 맞춘 표준적인 정규분포
#
# #### T분포(T- Distribution)
# ![image-3.png](attachment:image-3.png)
#
# - 표본으로 모평균(혹은 모평균 간의 차이)을 추정할 때 사용되는 분포
# - 표본 크기가 작을 때 정규분포보다 더 정확한 결과를 제공함
#
# #### 카이제곱분포
# ![image-4.png](attachment:image-4.png)
#
# - 독립적인 표준 정규 분포를 따르는 변수들의 제곱 합
# - 즉, 표본분산의 분포와 관련된 지표
# - 주로 독립성 검정, 적합도 검정 등에 사용됨
#
# #### F분포
# ![image-5.png](attachment:image-5.png)
#
# - 두 독립적인 카이 제곱 분포의 비율
# - 두 집단 간의 분산 차이를 비교하는 데 사용됨
#
#
#
# ## 추론통계
#
#
# ### 추정
# _모집단을 대표할 수 있는 일부를 표본으로 추출하여 분석한 통계량을 이용해서 모집단의 모수를 예측하는 과정_
#
# ### 검정
# _표본을 추출하여 얻은 표본통계량으로 모집단 모수에 대한 새로운 예상·가설 등이 옳다고 판단할 수 있는지를 평가하는 과정_
#
# ### 가설검정 과정
# _모집단의 실제 값이 얼마가 된다는 주장과 관련해, 표본의 정보를 사용해서 가설의 합당성 여부를 판정하는 과정_ <BR>
# **가설 설정 - 유의 수준 설정 - 검정통계량 산출 - 가설 기각/채택 판단**
#
# 1. 가설 설정
# 귀무가설 H0와 대립가설 H1를 설정 <BR>
# **귀무가설:** 기각하고자 하는 명제로 설정. 보통 “~는 차이가 없다”라는 명제. <BR>
# **대립가설:** 내가 주장하고자 하는 명제 로 설정. 보통 “~는 차이가 존재한다”라는 명제.
#
# 2. 유의수준 설정
# **유의수준:** _연구자가 결과를 판단할 때 허용할 수 있는 오류의 최대치_<BR>
# 주로 0.05, 즉 5%로 설정. 유의 수준은 연구자가 어떤 결정이 얼마나 신뢰할 만한지를 판단하는 기준이 됨.
#
# 3. 검정통계량 산출
# 데이터의 분포나 특징에 따라 T값, F값 등 어떤 통계량을 사용할지 정해야 하는 과정<BR>
# - Z값
# - T값
# - F값
#
# 4. 가설 기각/채택 판단
# **유의확률:** 가설 검정에 쓰일 수 있는 또 다른 척도 <BR>
# **유의확률(p)**가 **유의 수준(α)**보다 작을 시에는 귀무가설을 기각.
#
#
#
# ### 자료형에 따른 검정 방법
#
# #### [수치형 - 수치형] (피어슨)상관분석
# _두 변수간 피어슨 상관계수가 얼마나 유의미한지를 검정하는 방법_ <BR>
# 귀무가설: 두 변수간 선형 상관관계가 존재하지 않는다. <BR>
# 대립가설: 두 변수간 선형 상관관계가 존재한다. <BR>
#
# ##### Ex.
# ``` python
# import scipy.stats as spst <BR>
# spst.pearsonr(df['col1'], df['col2'])
# ```
#
#
# #### [범주형 - 수치형] F-test(ANOVA), T-test
# ##### T-test
# - 범주가 2개일 때 사용
# - t값: 두 평균 간 차이를 표준 오차로 나눈 값
# 귀무가설: 두 그룹의 평균에는 차이가 없다. <BR>
# 대립가설: 두 그룹의 평균에는 차이가 있다. <BR>
#
# ##### Ex.
# ``` python
# mincho = df.loc[df['민초여부'] == 'Yes', '수명'] <BR>
# no_mincho = df.loc[df['민초여부'] == 'No', '수명' ] <BR>
#
# spst.ttest_ind(mincho, no_mincho)
# ```
#
#
# ##### F-test(ANOVA)
# **F-통계량:** 분모 그룹과 분자 그룹의 분산 비 <BR>
# 귀무가설: 각 MBTI 그룹 별 수명 평균은 차이가 없다. <BR>
# 대립가설: 각 MBTI 그룹 별 수명 평균은 차이가 있다. <BR>
#
# ##### Ex.
# ``` python
# ISTP = MBTI.loc[MBTI['mbti'] == 'ISTP', '수명'] <BR>
# ESFP = MBTI.loc[MBTI['mbti'] == 'ESFP', '수명'] <BR>
# INFP = MBTI.loc[MBTI['mbti'] == 'INFP', '수명'] <BR>
#
# spst.f_oneway(ISTP, ESFP, INFP)
# ```
#
#
# #### [범주형 - 범주형] Chi2-test
# 귀무가설: 경영학과 여부와 갈색머리 여부는 관련이 없다. <BR>
# 대립가설: 경영학과 여부와 갈색머리 여부는 관련이 있다. <BR>
#
# ##### Ex.
# ``` python
# # 교차표 작성
# table = pd.crosstab(df['col1'], df['col2']) <BR>
#
# spst.chi2_contingency(table)
# ```
#
#
# #### [수치형 - 범주형]
# 수치형을 구간별로 잘라 범주화하지 않는 이상(ex 10대, 20대, …) 현재로써는 진행할 수 있는 검정 방법 X <BR>
# -> 범주형을 target, 수치형을 feature로 두고 모델을 만든 다음, 그 모델의 계수를 유의성 검정하여 그에 대한 p값을 보고 판단하는 방법을 사용
