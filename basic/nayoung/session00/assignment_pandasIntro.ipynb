# %% [markdown]
# # 1. Pandas란?
# - 데이터 분석에 특화된 파이썬 라이브러리
# - 행과 열로 이루어진 데이터 객체를 만들어 다룰 수 있게 되며, 보다 안정적으로 대용량의 데이터들을 처리하는데 매우 편리한 도구
# - Numpy의 확장판으로, `Numpy 기능` + `구조화 된 데이터 처리 기능`을 보유함

# %% [markdown]
# ## 1-1. Pandas의 주요 데이터 구조
#
# <img src = 'https://dandyrilla.github.io/images/2017-08-12/fig0.png'>
#
# |이름|차원|설명|
# |:-----------:|:-----------:|:-----------:|
# |Series|1차원|균일한 유형의 배열로 표시된 1차원 데이터|
# |DataFrame|2차원|인덱스가 같은 하나 이상의 Series가 모여진 2차원 표 형식의 데이터|
#
# > Pandas의 핵심은 DataFrame!

# %% [markdown]
# # 2. DataFrame 생성

# %% [markdown]
# ## 2-1. 라이브러리 불러오기

# %%
import pandas as pd

# %% [markdown]
# ## 2-2. 데이터프레임 만들기

# %%
# 괄호 안에서 Shift + Tab을 눌러보세요!
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **DataFrame의 속성값**
# ```python
# pd.DataFrame(data = None, index = None, columns = None, dtype = None, copy = False)
# ```
# - data : DataFrame을 생성할 데이터
# - index : index에 대한 정보, 미입력시 0부터 순차적으로 부여 (Optional)
# - columns : 열에 대한 이름값, 미입력시 0부터 순차적으로 부여 (Optional)
# - dtype : 각 column의 데이터 타입 명시, 미입력시 자체적으로 판단 (Optional)

# %% [markdown]
# #### [2차원 리스트로 데이터프레임 만들기]

# %%
lst = [['권유철', 22, '수학', '', '회장'], 
       ['김진하', 22, '사회', '경제', '교육팀장'],
       ['방서영', 24, '인공', '', '교육팀원'], 
       ['김민아', 23, '컴공', '', '교육팀원'],
       ['조대흠', 22, '영문', '인공', '교육팀원']]

df = pd.DataFrame(lst, columns=['이름', '학번', '전공', '복수전공', '역할'])
df = df.set_index('이름')

df
# Out:
#      학번  전공 복수전공    역할
# 이름
# 권유철  22  수학         회장
# 김진하  22  사회   경제  교육팀장
# 방서영  24  인공       교육팀원
# 김민아  23  컴공       교육팀원
# 조대흠  22  영문   인공  교육팀원

# %% [markdown]
# #### [사전으로 데이터프레임 만들기]

# %%
dic = {
    '이름': ['권유철', '김진하', '방서영', '김민아', '조대흠'],
    '학번': [22, 22, 24, 23, 22],
    '전공': ['수학', '사회', '인공', '컴공', '영문'],
    '복수전공': ['', '경제', '', '', '인공'],
    '역할': ['회장', '교육팀장', '교육팀원', '교육팀원', '교육팀원']
}

df2 = pd.DataFrame(**dic)
df2 = df2.set_index('이름')

df2
# Out:
#      학번  전공 복수전공    역할
# 이름
# 권유철  22  수학         회장
# 김진하  22  사회   경제  교육팀장
# 방서영  24  인공       교육팀원
# 김민아  23  컴공       교육팀원
# 조대흠  22  영문   인공  교육팀원

# %% [markdown]
# ## 2-3. 데이터프레임 타입 확인

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
# 컬럼별 데이터 타입 확인
# 각 컬럼은 다양한 데이터 타입으로 구성되며, 같은 컬럼의 데이터 타입은 동일하다
df.dtypes
# Out:
# 학번      int64
# 전공        str
# 복수전공      str
# 역할        str
# dtype: object

# %% [markdown]
# # 3. DataFrame 접근

# %% [markdown]
# ## 3-1. head, tail로 접근하기

# %% [markdown]
# - `head(개수)` : 위에서부터 개수만큼의 데이터 출력
# - `tail(개수)` : 밑에서부터 개수만큼의 데이터 출력

# %%
df.iloc[3]
# Out:
#      학번  전공 복수전공    역할
# 이름
# 권유철  22  수학         회장
# 김진하  22  사회   경제  교육팀장
# 방서영  24  인공       교육팀원

# %%
df.tail() #개수를 쓰지 않을 경우 5개만 출력
# Out:
#      학번  전공 복수전공    역할
# 이름
# 권유철  22  수학         회장
# 김진하  22  사회   경제  교육팀장
# 방서영  24  인공       교육팀원
# 김민아  23  컴공       교육팀원
# 조대흠  22  영문   인공  교육팀원

# %% [markdown]
# ## 3-2. 행명, 열명으로 접근하기: loc
# : `df.loc['행명', '열명']`
#
# 행: row / 열: column
#
# |접근 방법|사용 방법|
# |:--------------------------:|:-----------:|
# |행명|`df.loc["row4"]`|
# |행명 리스트|`df.loc[["row3", "row4", "row5"]]`|
# |행명 슬라이싱|`df["row3" : "row5"]`|
# |열명|`df.loc[ : , "col1"]`|`df["col1"]`|
# |열명 리스트|`df.loc[ : , ["col3", "col4", "col5"]` or `df[["col3", "col4", "col5"]]`|
# |열명 슬라이싱|`df.loc[ : , ["col3" : "col5"]`|

# %% [markdown]
# #### [값 1개 인덱싱]

# %%
df.loc['권유철', '역할']
# Out:
# '회장'

# %%
df[['전공']]
# Out:
#      전공
# 이름
# 권유철  수학
# 김진하  사회
# 방서영  인공
# 김민아  컴공
# 조대흠  영문

# %% [markdown]
# #### [한 줄 인덱싱]
# - 하나의 index만 조회 할 경우 Series Type으로 출력

# %%
# 행명으로 접근하기
# 컬럼 전체를 지정한다는 의미로 : 를 입력함
df.loc['김진하', :]  # df.loc['김진하']
# Out:
# 학번        22
# 전공        사회
# 복수전공      경제
# 역할      교육팀장
# Name: 김진하, dtype: object

# %%
# 열명으로 접근하기
df.loc[ : , '전공']  #df['전공']  #df.전공
# Out:
# 이름
# 권유철    수학
# 김진하    사회
# 방서영    인공
# 김민아    컴공
# 조대흠    영문
# Name: 전공, dtype: str

# %% [markdown]
# #### [여러 줄 인덱싱]
# - 여러 index를 조회 할 경우 DataFrame Type으로 출력

# %%
df.iloc[['방서영', '김민아'], 1:3]  #df.loc[['방서영', '김민아']]
# Out:
#      학번  전공 복수전공    역할
# 이름
# 방서영  24  인공       교육팀원
# 김민아  23  컴공       교육팀원

# %%
df.iloc[0:3, 1:3]  #df[['전공', '복수전공']]
# Out:
#      전공 복수전공
# 이름
# 권유철  수학
# 김진하  사회   경제
# 방서영  인공
# 김민아  컴공
# 조대흠  영문   인공

# %% [markdown]
# #### [슬라이싱]

# %%
df.iloc[0:3, 1:3]  #df.loc['김진하' : '조대흠']  #df['김진하' : '조대흠']
# Out:
#      학번  전공 복수전공    역할
# 이름
# 김진하  22  사회   경제  교육팀장
# 방서영  24  인공       교육팀원
# 김민아  23  컴공       교육팀원
# 조대흠  22  영문   인공  교육팀원

# %%
df.loc[:, '학번' : '복수전공']
# Out:
#      학번  전공 복수전공
# 이름
# 권유철  22  수학
# 김진하  22  사회   경제
# 방서영  24  인공
# 김민아  23  컴공
# 조대흠  22  영문   인공

# %% [markdown]
# ## 3-3. 위치 번호로 접근하기: iloc
# : `df.iloc['행번호', '열번호']`

# %% [markdown]
# |접근 방법|사용 방법|
# |:--------------------------:|:-----------:|
# |행 위치|`df.iloc[2]`|
# |행 위치 리스트|`df.iloc[[2, 6, 4]]`|
# |행 위치 슬라이싱|`df.iloc[2:5]` or `df[2:5]`|
# |열 위치|`df.iloc[ : , 3]`|
# |열 위치 리스트|`df.iloc[ : , [3, 2, 5]]`|
# |열 위치 슬라이싱|`df.iloc[ : , 3:5]`|

# %%
df
# Out:
#      학번  전공 복수전공    역할
# 이름
# 권유철  22  수학         회장
# 김진하  22  사회   경제  교육팀장
# 방서영  24  인공       교육팀원
# 김민아  23  컴공       교육팀원
# 조대흠  22  영문   인공  교육팀원

# %% [markdown]
# #### [0번 row, 3번 column에 해당하는 값 출력]

# %%
df.iloc[0, 3]
# Out:
# '회장'

# %% [markdown]
# #### [1번과 3번 row, 1번과 2번 column에 해당하는 데이터 출력]

# %%
df.iloc[0, 3]
# Out:
#      전공 복수전공
# 이름
# 김진하  사회   경제
# 김민아  컴공

# %% [markdown]
# #### [2번 ~ 마지막 row, 0번 ~ 2번 col에 해당하는 데이터 출력]

# %%
# 연속된 데이터 출력 --> 슬라이싱 활용

df.iloc[0:3, 1:3]
# Out:
#      학번  전공 복수전공
# 이름
# 방서영  24  인공
# 김민아  23  컴공
# 조대흠  22  영문   인공

# %% [markdown]
# ### 📌 [과제 12]
# 12. 프로미스나인 멤버들의 데이터프레임(df)에서 연속된 여러 줄을 찾는 과제입니다.<br/>
#     '지원'부터 '지헌'까지의 '학번'과 '역할'만을 확인할 수 있도록 출력해보세요! <br/>
#     (인덱싱과 슬라이싱 모두 사용)

# %%
import pandas as pd

lst = [['하영', 15, '컴공', 'AI', '회장'], 
       ['지원', 16, '경영', '심리', '교육팀장'],
       ['채영', 17, '경영', '빅사', '교육팀원'], 
       ['나경', 19, '경영', '빅사', '교육팀원'],
       ['지헌', 16, '경제', '빅사', '교육팀원']]

df12 = pd.DataFrame(lst, columns=['이름', '학번', '전공', '복수전공', '역할'])
df12 = df12.set_index('이름')

# %%
df12.loc['지원':'지헌', ['학번', '역할']]
# Out:
#     학번    역할
# 이름
# 지원  16  교육팀장
# 채영  17  교육팀원
# 나경  19  교육팀원
# 지헌  16  교육팀원

# %% [markdown]
# # 4. DataFrame 수정/추가/삭제

# %% [markdown]
# ## 4-1. 수정

# %% [markdown]
# #### [값 1개 수정]

# %%
df_new = df.copy()
df_new.loc['권유철', '역할']
# Out:
# '회장'

# %%
df_new.loc['권유철', '역할'] = '인싸'
df_new
# Out:
#      학번  전공 복수전공    역할
# 이름
# 권유철  22  수학         인싸
# 김진하  22  사회   경제  교육팀장
# 방서영  24  인공       교육팀원
# 김민아  23  컴공       교육팀원
# 조대흠  22  영문   인공  교육팀원

# %% [markdown]
# #### [한 줄 수정]

# %%
df_new.loc['김진하'] = [22, '사회', '경제', '교육팀짱']
df_new
# Out:
#      학번  전공 복수전공    역할
# 이름
# 권유철  22  수학         인싸
# 김진하  22  사회   경제  교육팀짱
# 방서영  24  인공       교육팀원
# 김민아  23  컴공       교육팀원
# 조대흠  22  영문   인공  교육팀원

# %%
# 역할 column의 모든 값을 동일하게 바꾸기
df_new.iloc[ : , df_new.columns.get_loc('역할')] = '15기'
df_new
# Out:
#      학번  전공 복수전공   역할
# 이름
# 권유철  22  수학       15기
# 김진하  22  사회   경제  15기
# 방서영  24  인공       15기
# 김민아  23  컴공       15기
# 조대흠  22  영문   인공  15기

# %% [markdown]
# #### [여러 줄 수정]

# %%
df_new.loc[['권유철', '김진하'], '전공'] = "-"
df_new
# Out:
#      학번  전공 복수전공   역할
# 이름
# 권유철  22   -       15기
# 김진하  22   -   경제  15기
# 방서영  24  인공       15기
# 김민아  23  컴공       15기
# 조대흠  22  영문   인공  15기

# %%
df_new[['복수전공', '역할']] = "?"
df_new
# Out:
#      학번  전공 복수전공 역할
# 이름
# 권유철  22   -    ?  ?
# 김진하  22   -    ?  ?
# 방서영  24  인공    ?  ?
# 김민아  23  컴공    ?  ?
# 조대흠  22  영문    ?  ?

# %% [markdown]
# #### [위치 번호로 값 수정]

# %%
df_new.iloc[[0, 1], [1, 2]] = "#"
df_new
# Out:
#      학번  전공 복수전공 역할
# 이름
# 권유철  22   -    #  #
# 김진하  22   -    #  #
# 방서영  24  인공    ?  ?
# 김민아  23  컴공    ?  ?
# 조대흠  22  영문    ?  ?

# %% [markdown]
# ## 4-2. 추가

# %%
df_new2 = df.copy()

# %% [markdown]
# #### [row 추가]

# %%
# 없는 인덱스명으로 데이터를 넣으면, 새로운 row가 추가됨
df_new2.loc['류시현'] = [21, '경영', '', '교육팀원']
df_new2
# Out:
#      학번  전공 복수전공    역할
# 이름
# 권유철  22  수학         회장
# 김진하  22  사회   경제  교육팀장
# 방서영  24  인공       교육팀원
# 김민아  23  컴공       교육팀원
# 조대흠  22  영문   인공  교육팀원
# 류시현  21  경영       교육팀원

# %% [markdown]
# #### [column 추가]

# %%
df_new2['기수'] = '15기'
df_new2
# Out:
#      학번  전공 복수전공    역할   기수
# 이름
# 권유철  22  수학         회장  15기
# 김진하  22  사회   경제  교육팀장  15기
# 방서영  24  인공       교육팀원  15기
# 김민아  23  컴공       교육팀원  15기
# 조대흠  22  영문   인공  교육팀원  15기
# 류시현  21  경영       교육팀원  15기

# %% [markdown]
# ## 4-3. 삭제
# 행 방향 axis=0 <br/>
# 열 방향 axis=1

# %%
df_new2.drop('권유철', axis = 0, inplace = True)  #inplace = False --> 기존의 df에 영향 X
df_new2
# Out:
#      학번  전공 복수전공    역할   기수
# 이름
# 김진하  22  사회   경제  교육팀장  15기
# 방서영  24  인공       교육팀원  15기
# 김민아  23  컴공       교육팀원  15기
# 조대흠  22  영문   인공  교육팀원  15기
# 류시현  21  경영       교육팀원  15기

# %%
df_new2.drop(['복수전공', '기수'], axis = 1, inplace = True)
df_new2
# Out:
#      학번  전공    역할
# 이름
# 김진하  22  사회  교육팀장
# 방서영  24  인공  교육팀원
# 김민아  23  컴공  교육팀원
# 조대흠  22  영문  교육팀원
# 류시현  21  경영  교육팀원

# %%
df_new2['역할']
df_new2
# Out:
#      학번  전공
# 이름
# 김진하  22  사회
# 방서영  24  인공
# 김민아  23  컴공
# 조대흠  22  영문
# 류시현  21  경영

# %% [markdown]
# ### 📌 [과제 13]
# 13. df_new3에 본인 포함 2명의 정보를 추가하고(행), 새로운 열을 만들어보자!

# %%
df_new3 = df.copy()
df_new3
# Out:
#      학번  전공 복수전공    역할
# 이름
# 권유철  22  수학         회장
# 김진하  22  사회   경제  교육팀장
# 방서영  24  인공       교육팀원
# 김민아  23  컴공       교육팀원
# 조대흠  22  영문   인공  교육팀원

# %%
df_new3.loc['김나영'] = [23, '컴공', '빅사', '16기']
df_new3.loc['고혜원'] = [23, '종교학', '경영학', '16기']
# Out:
#      학번  전공 복수전공    역할
# 이름
# 권유철  22  수학         회장
# 김진하  22  사회   경제  교육팀장
# 방서영  24  인공       교육팀원
# 김민아  23  컴공       교육팀원
# 조대흠  22  영문   인공  교육팀원
# 류시현  21  경영       교육팀원
# 김지윤  21  아텍   심리   부회장

# %%
# 새로운 열 만들기
df_new3['기수']='15기'
df_new3 # 확인
# Out:
#      학번  전공 복수전공    역할   기수
# 이름
# 권유철  22  수학         회장  15기
# 김진하  22  사회   경제  교육팀장  15기
# 방서영  24  인공       교육팀원  15기
# 김민아  23  컴공       교육팀원  15기
# 조대흠  22  영문   인공  교육팀원  15기
# 류시현  21  경영       교육팀원  15기
# 김지윤  21  아텍   심리   부회장  15기
