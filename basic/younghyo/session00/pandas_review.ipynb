# %% [markdown]
# ### 판다스의 개념과 판다스 라이브러리를 불러오는 방법에 대해 설명해주세요.
# 1. 판다스:
# - 데이터 분석에 특화된 파이썬 라이브러리
# - 행과 열로 이루어진 DataFrame을 기본틀로 사용
# - NumPy의 확장판 (numpy 기능 + 구조화된 데이터 처리 기능)
#
# 2. 판다스 라이브러리 불러오는 방법:
# import pandas as pd
#
# ### 데이터프레임이 무엇인지 정리해주세요.
# 데이터프레임: 컴퓨터로 정보를 정리하고 저장하는 도구
# 판다스에서 사용하는 주요 데이터 구조
# 행과 열로 이루어진 2차원의 배열 구조
#
# ### 데이터를 확인, 추출, 조작하는 방법을 간단하게 작성해주세요.
#
# - 데이터 확인
# head(), tail(), df.shape, df.info(), df.describe(), df.isnull(), df.dtypes, df.count(), df[열 이름].value_counts(), df[열 이름].unique()
#
# - 데이터 추출
# indexing    ex: df['노트북 브랜드']
# slicing     ex: df[start:end]
# df.loc[행 이름, 열 이름]
# df.iloc[행 순서, 열 순서]
# df[조건문]
#
# - 데이터 조작
# 추가: df['새로운 열 이름'] = 리스트
# 삭제: df.drop(labels, axis)
#
# ### 집계함수를 사용하는 방법을 쓰세요.
# - df['컬럼 명'].mean() : 평균
# - df['컬럼 명'].median() : 중앙값
# - df['컬럼 명'].std() : 표준편차
# - df['컬럼 명'].sum() : 합계
# - df['컬럼 명'].max() : 최대값
# - df['컬럼 명'].min() : 최소값
# - df.groupby('column명1')[’column명2'].집계함수()
# - df.groupby('column명1')[[’column명2']].집계함수()
